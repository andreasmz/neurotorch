# %%
import pims

# %%
path = r"D:\Eigene Datein\Programmieren\PYTHON\AG Heine Hiwi\Daten\control_R2-3.nd2"
pimsImg = pims.open(path)

# %%
_pimgsImg : pims.bioformats.BioformatsReader = pimsImg

# %%
import collections
metadata = collections.OrderedDict(sorted(_pimgsImg.get_metadata_raw().items()))
for k,v in metadata.items():
    print(f"'{k}': '{v}'")
# Out:
# '': '0'
# '(EPI)        N-STORM Angle': '24.8'
# '(FRAP)       Port 2': 'On'
# '(N-STORM)       Port 3': 'Off'
# '(Port 0)       Port 2': 'Off'
# '(Port 1)        Sola II, Shutter(Sola)': 'Closed'
# '- Equidistant (Duration 0 s)  TextInfoItem_': 'TextInfoItem_7'
# 'Analyzer Slider': 'Extracted'
# 'Average': '1'
# 'AverageCH': ''
# 'AverageToQuality': '0.0'
# 'AverageToQualityCH': ''
# 'Bertrand Lens, position': 'Out'
# 'Bottom': '0'
# 'Cam0Flip': 'False'
# 'Cam0Rotate180': 'False'
# 'Camera Name': 'Fusion, SN:000151'
# 'CameraFamilyName': ''
# 'CameraUniqueName': ''
# 'CameraUserName': ''
# 'CaptureMaxExposure': '1000.0'
# 'CaptureQuality': '25'
# 'ChannelColor': '65407'
# 'ChannelCount': '0'
# 'ChannelIsActive': 'True'
# 'ChannelName': 'Comp5'
# 'Color': '16777215'
# 'Columns': '2'
# 'Component Count': '1'
# 'DIAAdditionalFilterKey': ''
# 'DIAAdditionalFilterName': ''
# 'DIC Prism, position': 'Out'
# 'Data': '���S�￹P~WW�?�P~WW�����S��'
# 'DefectCorrectMode': 'True'
# ...

# %%
_pimgsImg.get_metadata_raw()
# Out:
# {'m_ibBertrandLensPosition': '0',
#  'm_sShutterShortName3': 'Sola',
#  'm_sShutterShortName2': 'Shutter (LASER)',
#  'm_ibLightNDFilterValid1': '0',
#  'm_sShutterShortName1': 'DIA LED',
#  'm_ibLightNDFilterValid0': '0',
#  'm_sShutterShortName0': 'FL-Lo',
#  'Z position for position, plane #409': 'ome.units.quantity.Length: value[2300.66], unit[reference frame] stored as java.lang.Double',
#  'Z position for position, plane #408': 'ome.units.quantity.Length: value[2300.66], unit[reference frame] stored as java.lang.Double',
#  'Z position for position, plane #407': 'ome.units.quantity.Length: value[2300.66], unit[reference frame] stored as java.lang.Double',
#  'Z position for position, plane #406': 'ome.units.quantity.Length: value[2300.66], unit[reference frame] stored as java.lang.Double',
#  'Z position for position, plane #405': 'ome.units.quantity.Length: value[2300.66], unit[reference frame] stored as java.lang.Double',
# ...
